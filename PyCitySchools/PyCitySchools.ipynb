#        'Rodriguez High School', 'Johnson High School', 'Ford High School',
#        'Thomas High School'], dtype=object)

# %%
numberofSchools= len(uniqueShools)
numberofSchools
# Out:
# 15

# %%
# Calculate the total number of students
countStudents= school_data_merged['Student ID'].count()
countStudents
# Out:
# 39170

# %%
# Calculate the total budget
totalBudget= school_data_merged['budget'].unique ()
sumtotalBudget = totalBudget.sum()
sumtotalBudget
# Out:
# 24649428

# %%
# Calculate the average math score 
average_mathScores= school_data_merged['math_score'].mean()
average_mathScores
# Out:
# 78.98537145774827

# %%
# Calculate the average reading score
average_readingScores= school_data_merged['reading_score'].mean()
average_readingScores
# Out:
# 81.87784018381414

# %%
# Calculate the percentage of students with a passing math score (70 or greater)
passingMathScores= school_data_merged[(school_data_merged['math_score'] >= 70)].count()['math_score']
percentage_passingMath=passingMathScores/school_data_merged.count()['math_score']
percentage_passingMath
# Out:
# 0.749808526933878

# %%
# Calculate the percentage of students with a passing reading score (70 or greater)
passingReadingScores= school_data_merged[(school_data_merged['reading_score'] >= 70)].count()['reading_score']
percentage_passingReading=passingReadingScores/school_data_merged.count()['reading_score']
percentage_passingReading
# Out:
# 0.8580546336482001

# %%
# Calculate the percentage of students who passed math **and** reading (% Overall Passing)
passingBoth= school_data_merged[(school_data_merged['math_score'] >=70) & (school_data_merged['reading_score']>=70)].count()['student_name']
percentage_passingBoth= passingBoth/school_data_merged.count()['Student ID']
percentage_passingBoth
# Out:
# 0.6517232575950983

# %%
districtSummary_df = pd.DataFrame({
    "Total Schools": [numberofSchools],
    "Total Students": [countStudents],
    "Total Budget": [sumtotalBudget],
    "Average Math Scores":[average_mathScores],
    "Average Reading Scores": [average_readingScores],
    "% Passing Math": [percentage_passingMath *100],
    "% Passing Reading": [percentage_passingReading *100],
    "% Overall Passing": [percentage_passingBoth *100]
    })
districtSummary_df
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Scores  \
# 0             15           39170      24649428            78.985371
#
#    Average Reading Scores  % Passing Math  % Passing Reading  \
# 0                81.87784       74.980853          85.805463
#
#    % Overall Passing
# 0          65.172326

# %%
# Optional: give the displayed data cleaner formatting

# %%
#School Name
indexed_schoolName= school_data_merged.set_index(['school_name'])

grouped_schoolName= indexed_schoolName.groupby(['school_name'])

print([grouped_schoolName])
grouped_schoolName.count().head(15)
# Out:
# ...
#                        Student ID  student_name  gender  grade  reading_score  \
# school_name
# Bailey High School           4976          4976    4976   4976           4976
# Cabrera High School          1858          1858    1858   1858           1858
# Figueroa High School         2949          2949    2949   2949           2949
# Ford High School             2739          2739    2739   2739           2739
# Griffin High School          1468          1468    1468   1468           1468
# Hernandez High School        4635          4635    4635   4635           4635
# Holden High School            427           427     427    427            427
# Huang High School            2917          2917    2917   2917           2917
# Johnson High School          4761          4761    4761   4761           4761
# Pena High School              962           962     962    962            962
# Rodriguez High School        3999          3999    3999   3999           3999
# ...

# %%
# School Type
grouped_schoolType= school_data[['school_name', 'type']].set_index('school_name')
grouped2_schoolType =  grouped_schoolType.squeeze()
grouped2_schoolType
# Out:
# school_name
# Huang High School        District
# Figueroa High School     District
# Shelton High School       Charter
# Hernandez High School    District
# Griffin High School       Charter
# Wilson High School        Charter
# Cabrera High School       Charter
# Bailey High School       District
# Holden High School        Charter
# Pena High School          Charter
# Wright High School        Charter
# Rodriguez High School    District
# Johnson High School      District
# Ford High School         District
# Thomas High School        Charter
# Name: type, dtype: object

# %%
# Total Students
grouped_totalStudent= school_data_merged['school_name'].value_counts()
grouped_totalStudent
# Out:
# Bailey High School       4976
# Johnson High School      4761
# Hernandez High School    4635
# Rodriguez High School    3999
# Figueroa High School     2949
# Huang High School        2917
# Ford High School         2739
# Wilson High School       2283
# Cabrera High School      1858
# Wright High School       1800
# Shelton High School      1761
# Thomas High School       1635
# Griffin High School      1468
# Pena High School          962
# Holden High School        427
# Name: school_name, dtype: int64

# %%
grouped_schoolBudget= school_data[['school_name', 'budget']].set_index('school_name')
grouped2_schoolBudget= grouped_schoolBudget.squeeze()
grouped2_schoolBudget
# Out:
# school_name
# Huang High School        1910635
# Figueroa High School     1884411
# Shelton High School      1056600
# Hernandez High School    3022020
# Griffin High School       917500
# Wilson High School       1319574
# Cabrera High School      1081356
# Bailey High School       3124928
# Holden High School        248087
# Pena High School          585858
# Wright High School       1049400
# Rodriguez High School    2547363
# Johnson High School      3094650
# Ford High School         1763916
# Thomas High School       1043130
# Name: budget, dtype: int64

# %%
# Per Student Budget
grouped_perstudentBudget= grouped2_schoolBudget/grouped_totalStudent
grouped_perstudentBudget
# Out:
# Bailey High School       628.0
# Cabrera High School      582.0
# Figueroa High School     639.0
# Ford High School         644.0
# Griffin High School      625.0
# Hernandez High School    652.0
# Holden High School       581.0
# Huang High School        655.0
# Johnson High School      650.0
# Pena High School         609.0
# Rodriguez High School    637.0
# Shelton High School      600.0
# Thomas High School       638.0
# Wilson High School       578.0
# Wright High School       583.0
# dtype: float64

# %%
# Average Math Score
grouped_averageMath= school_data_merged.groupby(['school_name'])['math_score'].mean()
grouped_averageMath

grouped_averageMath.head(15)
# Out:
# school_name
# Bailey High School       77.048432
# Cabrera High School      83.061895
# Figueroa High School     76.711767
# Ford High School         77.102592
# Griffin High School      83.351499
# Hernandez High School    77.289752
# Holden High School       83.803279
# Huang High School        76.629414
# Johnson High School      77.072464
# Pena High School         83.839917
# Rodriguez High School    76.842711
# Shelton High School      83.359455
# Thomas High School       83.418349
# Wilson High School       83.274201
# Wright High School       83.682222
# Name: math_score, dtype: float64

# %%
# Average Reading Score
grouped_averageReading= school_data_merged.groupby(['school_name'])['reading_score'].mean()
grouped_averageReading

grouped_averageReading.head(15)
# Out:
# school_name
# Bailey High School       81.033963
# Cabrera High School      83.975780
# Figueroa High School     81.158020
# Ford High School         80.746258
# Griffin High School      83.816757
# Hernandez High School    80.934412
# Holden High School       83.814988
# Huang High School        81.182722
# Johnson High School      80.966394
# Pena High School         84.044699
# Rodriguez High School    80.744686
# Shelton High School      83.725724
# Thomas High School       83.848930
# Wilson High School       83.989488
# Wright High School       83.955000
# Name: reading_score, dtype: float64

# %%
# % Passing Math
grouped_passingMath= school_data_merged[(school_data_merged['math_score'] >=70) & (school_data_merged['reading_score']>=70)].count()['student_name']
grouped
# Out:
#       Student ID       student_name gender grade          school_name  \
# 0              0       Paul Bradley      M   9th    Huang High School
# 1              1       Victor Smith      M  12th    Huang High School
# 2              2    Kevin Rodriguez      M  12th    Huang High School
# 3              3  Dr. Richard Scott      M  12th    Huang High School
# 4              4         Bonnie Ray      F   9th    Huang High School
# 5866        5866   Jamie Montgomery      F  12th  Shelton High School
# 5867        5867   Shannon Phillips      F  10th  Shelton High School
# 5868        5868        Todd Barber      M  11th  Shelton High School
# 5869        5869       Desiree King      F  12th  Shelton High School
# 5870        5870    Melissa Roberts      F  10th  Shelton High School
#
#       reading_score  math_score  School ID      type  size   budget
# 0                66          79          0  District  2917  1910635
# ...

# %%
# % Passing Reading
grouped_passingReading= school_data_merged.groupby(['type'])
grouped_passingReading.head(15)

# %%
# % Overall Passing (The percentage of students that passed math **and** reading.)

# %%
# Create an overview table that summarizes key metrics about each school
schoolSummary_df= pd.DataFrame({'School Type': grouped_schoolType,
                                'Total Students':grouped_totalStudent,
                                'Total School Budget': grouped_schoolBudget,
                                'Per Student Budget': grouped_perstudentBudget,
                                'Average Math Scores': grouped_averageMath,
                                'Average Reading Scores': grouped_averageReading,
                                '% Passing Math':
                                '% Passing Reading':
                                '% Overall Passing':
                                })
schoolSummary_df
# Out:
#   Input In [112]
#     '% Passing Reading':
#                        ^
# SyntaxError: invalid syntax

# %%
#Sort and display the top five performing schools by % overall passing.

# %%
#Sort and display the five worst-performing schools by % overall passing.

# %%
#Create a table that lists the average Math Score for students of each grade level (9th, 10th, 11th, 12th) at each school.

# %%
#Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.

# %%
# Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#  Average Math Score
#  Average Reading Score
#  % Passing Math
#  % Passing Reading
#  Overall Passing Rate (Average of the above two)

# %%
# Create a table that breaks down school performances based on School Size. Use 4 reasonable bins to group school size. Include in the table each of the following:
#  Average Math Score
#  Average Reading Score
#  % Passing Math
#  % Passing Reading
#  Overall Passing Rate (Average of the above two)

# %%
# Create a table that breaks down school performances based on School Type. Use 4 reasonable bins to group school type. Include in the table each of the following:
#  Average Math Score
#  Average Reading Score
#  % Passing Math
#  % Passing Reading
#  Overall Passing Rate (Average of the above two)
